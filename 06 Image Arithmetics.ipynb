# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img1 = cv2.imread("images/lenna.png")
img2 = cv2.imread("images/sun.png")
img3 = np.hstack([img1, img2])

cv2.imshow("Two Images", img3)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1.shape
# Out:
# (512, 512, 3)

# %%
img2.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ##### Addition of images

# %%
added_img = cv2.add(img1, img2)

# %%
cv2.imshow("Added Image", added_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1[0,0,0]
# Out:
# 125

# %%
img2[0,0,0]
# Out:
# 64

# %%
added_img[0,0,0]
# Out:
# 189

# %%
added_img1 = img1 + img2

# %%
cv2.imshow("Added Images", added_img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
added_img1[0,0,0]
# Out:
# 189

# %% [markdown]
# ##### Image subtraction

# %%
subtracted_img = cv2.subtract(img1, img2)

# %%
cv2.imshow("subtracted Images", subtracted_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
subtracted_img1 = img1 - img2

# %%
cv2.imshow("subtracted Images", subtracted_img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
subtracted_img
# Out:
# array([[[ 61,  33, 103],
#         [ 61,  33, 103],
#         [ 69,  33, 100],
#         ...,
#         [ 63,  63, 122],
#         [ 53,  46, 115],
#         [ 34,  16,  95]],
#
#        [[ 61,  36, 105],
#         [ 61,  36, 105],
#         [ 69,  36, 102],
#         ...,
#         [ 63,  64, 124],
#         [ 52,  47, 116],
#         [ 33,  17,  96]],
#
#        [[ 61,  36, 105],
#         [ 61,  36, 105],
#         [ 70,  36, 102],
#         ...,
#         [ 63,  66, 125],
#         [ 52,  48, 117],
#         [ 32,  17,  96]],
#
#        ...,
#
#        [[ 59,   4,  72],
#         [ 60,   5,  73],
#         [ 58,  14,  81],
#         ...,
#         [ 79,  38, 144],
#         [ 73,  38, 147],
#         [ 79,  40, 160]],
#
#        [[ 57,  11,  73],
#         [ 56,  10,  72],
#         [ 62,  24,  89],
#         ...,
#         [ 73,  34, 150],
#         [ 80,  45, 161],
#         [ 80,  50, 167]],
#
#        [[ 56,  10,  72],
#         [ 56,  11,  73],
#         [ 62,  26,  92],
# ...

# %%
new_img = added_img - img2

# %%
cv2.imshow("Final Images", new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
new_img = added_img - img1

# %%
cv2.imshow("Final Images", new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
new_img = added_img + subtracted_img

# %%
cv2.imshow("Final Images", new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Addition with scaler

# %%
img_add = img1 + 30

# %%
cv2.imshow("Final Image", img_add)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1[0,0]
# Out:
# array([125, 137, 226], dtype=uint8)

# %%
img_add[0,0]
# Out:
# array([155, 167,   0], dtype=uint8)

# %%
img1[40,40], img_add[40,40]
# Out:
# (array([105, 133, 228], dtype=uint8), array([135, 163,   2], dtype=uint8))

# %%
img_sub = img1 - 50

# %%
cv2.imshow("Final Image", img_sub)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Image blending

# %%
alpha = 0.5
img_blend = cv2.addWeighted(img1, alpha, img2, 1 - alpha, 0)

# %%
cv2.imshow("Blended Image", img_blend)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
alpha = 0.2
img_blend = cv2.addWeighted(img1, alpha, img2, 1 - alpha, 0)

cv2.imshow("Blended Image", img_blend)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
alpha = 0.8
img_blend = cv2.addWeighted(img1, alpha, img2, 1 - alpha, 0)

cv2.imshow("Blended Image", img_blend)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Multiplication on images

# %%
img_mul = cv2.multiply(img1, 1.5)

# %%
cv2.imshow("Brightened Image", img_mul)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_mul = cv2.multiply(img1, 2.5)
cv2.imshow("Brightened Image", img_mul)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Division on images

# %%
img_div = cv2.divide(img1, 1.5)
cv2.imshow("Darkened Image", img_div)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_div = cv2.divide(img2, 2.5)
cv2.imshow("Darkened Image", img_div)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Bitwise operations

# %%
6 & 5
# Out:
# 4

# %%
0b110 & 0b101
# Out:
# 4

# %%
6 | 5
# Out:
# 7

# %%
~5
# Out:
# -6

# %%
input1 = cv2.imread("images/input1.png", 0)
input2 = cv2.imread("images/input2.png", 0)

# %%
plt.subplot(1,2,1)
plt.imshow(input1, cmap = 'gray')
plt.subplot(1,2,2)
plt.imshow(input2, cmap = 'gray')

# %%
input1.shape, input2.shape
# Out:
# ((250, 499), (250, 499))

# %% [markdown]
# ##### Bitwise OR

# %%
img_or = cv2.bitwise_or(input1, input2)

# %%
plt.subplot(1,3,1)
plt.imshow(input1, cmap = 'gray')
plt.subplot(1,3,2)
plt.imshow(input2, cmap = 'gray')
plt.subplot(1,3,3)
plt.title("ORed Image")
plt.imshow(img_or, cmap = 'gray')

# %% [markdown]
# ##### Bitwise AND

# %%
img_and = cv2.bitwise_and(input1, input2)

# %%
plt.subplot(1,3,1)
plt.imshow(input1, cmap = 'gray')
plt.subplot(1,3,2)
plt.imshow(input2, cmap = 'gray')
plt.subplot(1,3,3)
plt.title("ANDed Image")
plt.imshow(img_and, cmap = 'gray')

# %% [markdown]
# ##### Bitwise XOR

# %%
img_xor= cv2.bitwise_xor(input1, input2)

# %%
plt.subplot(1,3,1)
plt.imshow(input1, cmap = 'gray')
plt.subplot(1,3,2)
plt.imshow(input2, cmap = 'gray')
plt.subplot(1,3,3)
plt.title("XORed Image")
plt.imshow(img_xor, cmap = 'gray')

# %% [markdown]
# ##### Bitwise NOT

# %%
img_not1 = cv2.bitwise_not(input1)
img_not2 = cv2.bitwise_not(input2)

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,4,1)
plt.imshow(input1, cmap = 'gray')
plt.subplot(1,4,2)
plt.title("NOT Image")
plt.imshow(img_not1, cmap = 'gray')
plt.subplot(1,4,3)
plt.imshow(input2, cmap = 'gray')
plt.subplot(1,4,4)
plt.title("NOT Image")
plt.imshow(img_not2, cmap = 'gray')

# %%
img_new = cv2.bitwise_and(img1, img2)

# %%
cv2.imshow("ANDed Image", img_new)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Image Masking

# %%
import cv2 
import numpy as np 
  
# Reading an image 
img = cv2.imread('images/rgy.jpg') 
  
# The kernel to be used for dilation purpose 
kernel = np.ones((5, 5), np.uint8) 
  
# converting the image to HSV format 
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) 
  
# defining the lower and upper values of HSV, 
# this will detect yellow colour 
Lower_hsv = np.array([20, 70, 100]) 
Upper_hsv = np.array([30, 255, 255]) 
  
# creating the mask by eroding,morphing, 
# dilating process 
Mask = cv2.inRange(hsv, Lower_hsv, Upper_hsv) 
Mask = cv2.erode(Mask, kernel, iterations=1) 
Mask = cv2.morphologyEx(Mask, cv2.MORPH_OPEN, kernel) 
Mask = cv2.dilate(Mask, kernel, iterations=1) 
  
# Inverting the mask by 
# performing bitwise-not operation 
Mask = cv2.bitwise_not(Mask) 
  
# Displaying the image 
cv2.imshow('Mask', Mask) 
cv2.waitKey(0)  
cv2.destroyAllWindows()

# %% [markdown]
# ##### Splitting channels

# %%
img1.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(img1)

# %%
b, g, r = cv2.split(img1)

# %%
b.shape
# Out:
# (512, 512)

# %%
g.shape
# Out:
# (512, 512)

# %%
r.shape
# Out:
# (512, 512)

# %%
plt.figure(figsize=(16,8))
plt.subplot(131)
plt.title("Blue")
plt.imshow(b, cmap = 'gray')
plt.subplot(132)
plt.title("Green")
plt.imshow(g, cmap = 'gray')
plt.subplot(133)
plt.title("Red")
plt.imshow(r, cmap = 'gray')

# %%
img_rgb = cv2.merge([r,g,b])

# %%
plt.imshow(img_rgb)

# %%
img_brg = cv2.merge([b,r,g])
img_rbg = cv2.merge([r,b,g])
img_grb = cv2.merge([g,r,b])

# %%
plt.figure(figsize=(16,8))
plt.subplot(131)
plt.title("BRG")
plt.imshow(img_brg)
plt.subplot(132)
plt.title("RBG")
plt.imshow(img_rbg)
plt.subplot(133)
plt.title("GRB")
plt.imshow(img_grb)

# %%
new_channel = np.zeros([512,512], dtype = np.uint8) + 255

# %%
new_channel
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
new_channel[23,45] = 100

# %%
plt.imshow(new_channel, cmap = 'gray')

# %%
cv2.imshow('New Channel', new_channel) 
cv2.waitKey(0)  
cv2.destroyAllWindows()

# %%
new_img = cv2.merge([r,b,new_channel])

# %%
plt.imshow(new_img)

# %%
new_img = cv2.merge([r,new_channel,b])

# %%
plt.imshow(new_img)

# %%
img_sun = cv2.imread("images/sun.png")

# %%
bs, gs, rs = cv2.split(img_sun)

# %%
new_img1 = cv2.merge([rs, g ,b])

# %%
plt.imshow(new_img1)

# %%
new_img2 = cv2.merge([r, gs ,b])
plt.imshow(new_img2)

# %%
img1
# Out:
# array([[[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        ...,
#
#        [[ 60,  18,  84],
#         [ 60,  18,  84],
#         [ 58,  27,  92],
#         ...,
#         [ 84,  73, 173],
#         [ 76,  68, 172],
#         [ 79,  62, 177]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
#         ...,
#         [ 79,  70, 179],
#         [ 81,  71, 181],
#         [ 81,  74, 185]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
# ...

# %%
img_hsv = cv2.cvtColor(img1, cv2.COLOR_BGR2HSV)

# %%
cv2.imshow('HSV Color Space', img_hsv) 
cv2.waitKey(0)  
cv2.destroyAllWindows()

# %%
img_lab = cv2.cvtColor(img1, cv2.COLOR_BGR2LAB)

# %%
cv2.imshow('LAB Color Space', img_lab) 
cv2.waitKey(0)  
cv2.destroyAllWindows()

# %%
from PIL import Image

# %%
img_pil = Image.open("images/lenna.png")

# %%
img_pil.mode
# Out:
# 'RGB'

# %%
img_cmyk = img_pil.convert("CMYK")

# %%
img_cmyk.mode
# Out:
# 'CMYK'

# %%
img_hsv = img_pil.convert("HSV")

# %%
img_hsv.mode
# Out:
# 'HSV'

# %%
img_lab = img_pil.convert("LAB")

# %%
img_lab.show()
